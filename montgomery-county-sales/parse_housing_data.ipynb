# %%
import os

mypath = os.path.join('zillow-data')
json_files = [os.path.join(mypath, f) for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]

# %%
import json
import pandas as pd


# Utility function to convert currency string to float.
def value_to_float(x):
    
    # Remove the $ and , characters from x.
    x = x.replace('$', '')
    x = x.replace(',', '')
        
    # Handle thousands.
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    
    # Handle millions.
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    
    return float(x)

# Initialize a list to keep track of all homes.
all_homes = []

for fn in json_files:
    
    home_info = None
    
    try:
        f = open(fn)
        home_info = json.load(f)
    except Exception as e:
        print (f'Exception {e} encountered!')
        
    current_homes = home_info['cat1']['searchResults']['mapResults']
    
    for home in current_homes:
        
        # If the price field is not filled in, continue.
        if 'price' not in home or home['price'] == '':
            continue
        
        # If the hdpData field does not exist, continue.
        if 'hdpData' not in home:
            continue
        
        h = home['hdpData']['homeInfo'].copy()
        h['price'] = value_to_float(home['price'])
        
        # Parse the address.
        h['addr'] = home['detailUrl'].split('/')[2].replace('-', ' ').lower()
    
        # Insert this home in all homes.
        all_homes.append(h)

# Load in the dataframe.
sold_homes_df = pd.DataFrame(all_homes)

sold_homes_df = sold_homes_df.drop(['providerListingID', 
                                    'newConstructionType',
                                    'unit',
                                    'videoCount',
                                    'contingentListingType',
                                    'isRentalWithBasePrice',
                                    'datePriceChanged',
                                    'priceReduction',
                                    'priceChange',
                                    'openHouse',
                                    'open_house_info',
                                    'group_type',
                                    'grouping_name',
                                    'priceSuffix'],
                                  axis=1)

# We do not need some columns and do not care if they contain NaN values. Drop those columns.

pd.set_option('display.max_columns', None)
print (f'All sold homes: {sold_homes_df.shape}')
sold_homes_df.head(10)
# Out:
# All sold homes: (15818, 32)
#         zpid zipcode           city state   latitude  longitude     price  \
# 0   37151520   20854        Potomac    MD  39.043986 -77.256456  800000.0
# 1  246554034   20814       Bethesda    MD  39.022005 -77.107586  800000.0
# 2   37181535   20816       Bethesda    MD  38.958795 -77.111890  800000.0
# 3   37182564   20817       Bethesda    MD  38.974071 -77.131494  800000.0
# 4   37096069   20854        Potomac    MD  39.041634 -77.172128  800000.0
# 5   37172594   20817       Bethesda    MD  38.999271 -77.113950  800000.0
# 6   37286594   20910  Silver Spring    MD  39.003488 -77.038573  800000.0
# 7   37282676   20910  Silver Spring    MD  38.998174 -77.016036  800000.0
# 8   37173681   20815    Chevy Chase    MD  39.000000 -77.076248  800000.0
# 9   37181682   20815    Chevy Chase    MD  38.980442 -77.063683  800000.0
#
#         dateSold  bathrooms  bedrooms  livingArea       homeType  \
# 0  1625641200000        4.0       5.0      3650.0  SINGLE_FAMILY
# 1  1617606000000        1.0       2.0      1400.0  SINGLE_FAMILY
# 2  1624604400000        3.0       4.0      2390.0  SINGLE_FAMILY
# 3  1604563200000        3.0       4.0      1826.0  SINGLE_FAMILY
# 4  1620370800000        3.0       4.0      2810.0  SINGLE_FAMILY
# 5  1627282800000        5.0       5.0      2700.0  SINGLE_FAMILY
# 6  1613980800000        4.0       3.0      2304.0  SINGLE_FAMILY
# 7  1610092800000        3.0       4.0      1900.0  SINGLE_FAMILY
# 8  1609142400000        2.0       5.0      2115.0  SINGLE_FAMILY
# 9  1616050800000        3.0       3.0      1913.0  SINGLE_FAMILY
#
#       homeStatus  daysOnZillow  isFeatured  shouldHighlight  zestimate  \
# 0  RECENTLY_SOLD            -1       False            False   809700.0
# 1  RECENTLY_SOLD            -1       False            False   636600.0
# 2  RECENTLY_SOLD            -1       False            False   812000.0
# 3  RECENTLY_SOLD            -1       False            False   867900.0
# 4  RECENTLY_SOLD            -1       False            False   815700.0
# 5  RECENTLY_SOLD            -1       False            False   806500.0
# 6  RECENTLY_SOLD            -1       False            False   842700.0
# 7  RECENTLY_SOLD            -1       False            False   848800.0
# 8  RECENTLY_SOLD            -1       False            False   858700.0
# 9  RECENTLY_SOLD            -1       False            False   836000.0
#
#    rentZestimate      listing_sub_type  isUnmappable  isPreforeclosureAuction  \
# 0         4250.0                    {}         False                    False
# 1         2499.0                    {}         False                    False
# 2         4364.0                    {}         False                    False
# 3         4058.0                    {}         False                    False
# 4         3249.0                    {}         False                    False
# 5         5269.0  {'is_newHome': True}         False                    False
# 6         3270.0                    {}         False                    False
# 7         2856.0                    {}         False                    False
# 8         3652.0                    {}         False                    False
# 9         3599.0                    {}         False                    False
#
#   homeStatusForHDP  priceForHDP  isNonOwnerOccupied  isPremierBuilder  \
# 0    RECENTLY_SOLD     800000.0                True             False
# 1    RECENTLY_SOLD     800000.0                True             False
# 2    RECENTLY_SOLD     800000.0                True             False
# 3    RECENTLY_SOLD     800000.0                True             False
# 4    RECENTLY_SOLD     800000.0                True             False
# 5         FOR_SALE    1625000.0                True              True
# 6    RECENTLY_SOLD     800000.0                True             False
# 7    RECENTLY_SOLD     800000.0                True             False
# 8    RECENTLY_SOLD     800000.0                True             False
# 9    RECENTLY_SOLD     800000.0                True             False
#
#    isZillowOwned currency country  taxAssessedValue  lotAreaValue lotAreaUnit  \
# 0          False      USD     USA         1081300.0      5.100000       acres
# 1          False      USD     USA          507900.0      0.250000       acres
# 2          False      USD     USA          721567.0   8750.000000        sqft
# 3          False      USD     USA          697767.0   9148.000000        sqft
# 4          False      USD     USA          611000.0   9811.000000        sqft
# 5          False      USD     USA          801500.0   6900.000000        sqft
# 6          False      USD     USA          534800.0   6570.000000        sqft
# 7          False      USD     USA          617567.0   6604.000000        sqft
# 8          False      USD     USA          658567.0      0.379293       acres
# 9          False      USD     USA          715233.0   8679.000000        sqft
#
#                                         addr
# 0   12400 beall mountain ln potomac md 20854
# 1       10155 laureate way bethesda md 20814
# 2   5516 massachusetts ave bethesda md 20816
# 3          6504 marjory ln bethesda md 20817
# 4          11502 regency dr potomac md 20854
# 5        5616 southwick st bethesda md 20817
# 6    1701 highland dr silver spring md 20910
# 7   505 deerfield ave silver spring md 20910
# 8  8801 kensington pkwy chevy chase md 20815
# 9       3200 winnett rd chevy chase md 20815

# %%
pd.reset_option('display.max_columns', None)

# %%
# Drop null rows.
sold_homes_df.dropna()

print (f'All sold homes after dropping null values: {sold_homes_df.shape}')
sold_homes_df.head(10)
# Out:
# All sold homes after dropping null values: (15818, 32)
#         zpid zipcode           city state   latitude  longitude     price  \
# 0   37151520   20854        Potomac    MD  39.043986 -77.256456  800000.0
# 1  246554034   20814       Bethesda    MD  39.022005 -77.107586  800000.0
# 2   37181535   20816       Bethesda    MD  38.958795 -77.111890  800000.0
# 3   37182564   20817       Bethesda    MD  38.974071 -77.131494  800000.0
# 4   37096069   20854        Potomac    MD  39.041634 -77.172128  800000.0
# 5   37172594   20817       Bethesda    MD  38.999271 -77.113950  800000.0
# 6   37286594   20910  Silver Spring    MD  39.003488 -77.038573  800000.0
# 7   37282676   20910  Silver Spring    MD  38.998174 -77.016036  800000.0
# 8   37173681   20815    Chevy Chase    MD  39.000000 -77.076248  800000.0
# 9   37181682   20815    Chevy Chase    MD  38.980442 -77.063683  800000.0
#
#         dateSold  bathrooms  bedrooms  ...  priceForHDP isNonOwnerOccupied  \
# 0  1625641200000        4.0       5.0  ...     800000.0               True
# 1  1617606000000        1.0       2.0  ...     800000.0               True
# 2  1624604400000        3.0       4.0  ...     800000.0               True
# 3  1604563200000        3.0       4.0  ...     800000.0               True
# 4  1620370800000        3.0       4.0  ...     800000.0               True
# 5  1627282800000        5.0       5.0  ...    1625000.0               True
# 6  1613980800000        4.0       3.0  ...     800000.0               True
# 7  1610092800000        3.0       4.0  ...     800000.0               True
# 8  1609142400000        2.0       5.0  ...     800000.0               True
# 9  1616050800000        3.0       3.0  ...     800000.0               True
#
#   isPremierBuilder  isZillowOwned  currency  country  taxAssessedValue  \
# 0            False          False       USD      USA         1081300.0
# 1            False          False       USD      USA          507900.0
# 2            False          False       USD      USA          721567.0
# 3            False          False       USD      USA          697767.0
# 4            False          False       USD      USA          611000.0
# 5             True          False       USD      USA          801500.0
# 6            False          False       USD      USA          534800.0
# 7            False          False       USD      USA          617567.0
# 8            False          False       USD      USA          658567.0
# 9            False          False       USD      USA          715233.0
#
#    lotAreaValue lotAreaUnit                                       addr
# 0      5.100000       acres   12400 beall mountain ln potomac md 20854
# 1      0.250000       acres       10155 laureate way bethesda md 20814
# 2   8750.000000        sqft   5516 massachusetts ave bethesda md 20816
# 3   9148.000000        sqft          6504 marjory ln bethesda md 20817
# 4   9811.000000        sqft          11502 regency dr potomac md 20854
# 5   6900.000000        sqft        5616 southwick st bethesda md 20817
# 6   6570.000000        sqft    1701 highland dr silver spring md 20910
# 7   6604.000000        sqft   505 deerfield ave silver spring md 20910
# 8      0.379293       acres  8801 kensington pkwy chevy chase md 20815
# 9   8679.000000        sqft       3200 winnett rd chevy chase md 20815
#
# [10 rows x 32 columns]

# %%
sold_homes_df.to_csv(os.path.join('sale_price.csv'), index=False)
